# %% [markdown]
# # Shenzhen Taxi Data - Reframe with Machine Learning
#
# Research Team: Xinyue Hu, Zhixun Wang
#
# Abstract；The problem comes from when we tried to visualize the data set, we found out that about 10% data were incorrectly cutted. Thus we are trying to find out the real pattern for the data by introducing the machine learning techniques. Then we will present the visualization with the new data.

# %%
# First, we import the dataset with pandas.
import numpy as np
import pandas as pd

datapath = 'datasets/'
data = pd.read_csv(datapath + 'data13_indv_comb.csv',delimiter = ',')

# %%
data.describe
# Out:
# <bound method NDFrame.describe of           taxiid             datetime         lon        lat  velocity  angle  \
# 0       SZB7CP47  2013-01-15 02:00:43  114.104851  22.549850        22   8100
# 1       SZB7CP47  2013-01-15 02:01:38  114.105934  22.546583        20   6075
# 2       SZB7CP47  2013-01-15 02:02:33  114.105934  22.546583         0   6075
# 3       SZB7CP47  2013-01-15 02:03:28  114.106430  22.544649        14   2025
# 4       SZB7CP47  2013-01-15 02:04:23  114.113434  22.545816        48   4050
# 5       SZB7CP47  2013-01-15 02:35:56  114.116982  22.546467        14   4050
# 6       SZB7CP47  2013-01-15 02:36:51  114.116997  22.548149        14   2025
# 7       SZB7CP47  2013-01-15 02:37:46  114.122620  22.548300        33   2025
# 8       SZB7CP47  2013-01-15 02:38:41  114.122536  22.550516        15  14175
# 9       SZB7CP47  2013-01-15 02:39:54  114.122269  22.551634         4  14175
# 10      SZB7CP47  2013-01-15 02:40:48  114.122818  22.552017         1   2025
# ...
